# %% [markdown]
# <a href="https://colab.research.google.com/github/nmawadah354-cmd/DasarPPLG-X-2627/blob/main/Tugas%20pemrograman%20menghitung%20luas%20persegi%20panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR LUAS PERSEGI PANJANG
# nama kelompok: NEXACODE
# Nama anggota :
# 1. Nurma
# 2. Dina
# 3. Raisya
# 4. Alyaa
# 5. Aghnan
# 6. Fadhil
# 7. Davi

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luaspersegipanjang.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float panjang, lebar, luas;
#
#     cout << "masukan panjang: ";
#     cin >> panjang;
#     cout << "masukan lebar: ";
#     cin >> lebar;
#
#     luas = panjang * lebar;
#     cout << "luas persegi panjang = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting luaspersegipanjang.cpp

# %%
! g++ luaspersegipanjang.cpp -o main

# %%
! ./main
# Out:
# masukan panjang: ^C
