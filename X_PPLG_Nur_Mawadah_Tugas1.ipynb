# %% [markdown]
# <a href="https://colab.research.google.com/github/nmawadah354-cmd/DasarPPLG-X-2627/blob/main/X_PPLG_Nur_Mawadah_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 praktik membuat tipe data dan variabel
# Nama kelompok: NEXACODE
# Nama anggota:
# 1. Nur mawadah
# 2. Syafira meidina syarif
# 3. Raisya putri dermawan
# 4. Alyaa Rahma Thalita
# 5. Aghnan aiszar kamaludin
# 6. Davi ramadhan pratama
# 7. Teuku Muhammad Fadhil

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Sepatu Adidas Ultraboost";
#     int jumlah = 30;
#     double harga = 2199000.00;
#     char kategori = 'C';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Sepatu Adidas Ultraboost
# Kategori    : C
# Jumlah      : 30
# Harga       : Rp 2.199e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
