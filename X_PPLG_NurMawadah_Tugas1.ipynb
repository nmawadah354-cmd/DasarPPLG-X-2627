# %% [markdown]
# <a href="https://colab.research.google.com/github/nmawadah354-cmd/DasarPPLG-X-2627/blob/main/X_PPLG_NurMawadah_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 2 membuat tipe data dan variabel
# Nama kelompok NEXACODE
# Nama anggota
# 1. Nur Mawadah
# 2. Syafira meidina syarif
# 3. Raisya putri dermawan
# 4. Alyaa Rahma Thalita
# 5. Aghnan aiszar kamaludin
# 6. Teuku Muhammad Fadhil
# 7. Davi ramadhan pratama

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : Nurma
# Masukkan Umur Anda     : 17
#
# Halo Nurma, ternyata umur kamu 17 tahun ya!
